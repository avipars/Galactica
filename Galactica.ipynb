# %% [markdown]
# <a href="https://colab.research.google.com/github/avipars/Galactica/blob/main/Galactica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install dependencies and load model (SET set runtime to GPU or TPU)

# %%
# !pip install galai

import galai as gal
#https://github.com/paperswithcode/galai/blob/3a724f562af1a0c8ff97a096c5fbebe579e2160f/notebooks/Introduction%20to%20Galactica%20Models.ipynb
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 49.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 66.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.9 MB/s eta 0:00:00
# ...
#   Created wheel for galai: filename=galai-1.1.6-py3-none-any.whl size=24725 sha256=b16870be144d3725ac0bcef8dada5f68fc8b1cf7d4c99e3a2db3e3634b26ed0f
#   Stored in directory: /root/.cache/pip/wheels/c6/fd/e4/a3d84c0ac004834f6c17e3979d4eb90d8028d755536aead894
# ...

# %%
model = gal.load_model("base") #base model for sample

model.generate("Scaled dot product attention:\n\n\\[")
# Out:
# 'Scaled dot product attention:\n\n\\[ \\displaystyle\\text{Scaled dot product attention}(Q,K,V)=\\text{softmax}(\\frac{QK^{%\nT}}{\\sqrt{d_{k}}})V \\] (1)\n\n'

# %%
#https://github.com/paperswithcode/galai/blob/3a724f562af1a0c8ff97a096c5fbebe579e2160f/notebooks/Introduction%20to%20Galactica%20Models.ipynb

from galai.notebook_utils import *

# %%
prompt = "The Riemann zeta function is given by:\n\n\\["
output = model.generate(prompt, max_new_tokens=60)
display_latex(output)
# Out:
# The Riemann zeta function is given by:
#
# $$ \zeta(s)=\sum_{n=1}^{\infty}\frac{1}{n^{s}},\quad\Re(s)&gt;1. $$
#
# The Riemann hypothesis (RH) states that the zeros of

# %% [markdown]
# Prompt a logic trick question with the base model

# %%
prompt = f"Question: A bat and a ball cost $\\$1.10$ in total. The bat costs $\\$1.00$ more than the ball. How much does the ball cost?\n\nAnswer:"
display_markdown(model.generate(prompt, new_doc=True, max_new_tokens=250))
# Out:
# <p>Question: A bat and a ball cost $\$1.10$ in total. The bat costs $\$1.00$ more than the ball. How much does the ball cost?</p>
# <p>Answer: $\$1.10$</p>
# <p>&lt;work&gt;</p>
# <p>The bat costs $\$1.00$ more than the ball.</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$1.00$</p>
# <p>$\$1.10 = \$1.00 + \$</p>

# %% [markdown]
# Same question with a huge model that should get it right

# %%
model = gal.load_model("huge", parallelize=True)
prompt = f"Question: A bat and a ball cost $\\$1.10$ in total. The bat costs $\\$1.00$ more than the ball. How much does the ball cost?\n\nAnswer:"
display_markdown(model.generate(prompt, new_doc=True, max_new_tokens=250))
# Out:
# /usr/local/lib/python3.10/dist-packages/galai/__init__.py:118: UserWarning: parallelize=True requires at least two GPUs. Setting it back to False.
#   warnings.warn(
# (…)-120b/resolve/main/tokenizer_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# (…)lactica-120b/resolve/main/tokenizer.json:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# (…)20b/resolve/main/special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# (…)/galactica-120b/resolve/main/config.json:   0%|          | 0.00/783 [00:00<?, ?B/s]
# (…)esolve/main/pytorch_model.bin.index.json:   0%|          | 0.00/135k [00:00<?, ?B/s]
# pytorch_model-00001-of-00026.bin:   0%|          | 0.00/9.46G [00:00<?, ?B/s]
# pytorch_model-00002-of-00026.bin:   0%|          | 0.00/9.86G [00:00<?, ?B/s]
